# %% [markdown]
# ## Part 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv('Sales_data.csv', parse_dates = True, index_col='InvoiceDate')
df
# Out:
# c:\Users\hslim\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     Invoice StockCode                          Description  \
# InvoiceDate
# 2009-12-01 07:45:00  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 2009-12-01 07:45:00  489434    79323P                   PINK CHERRY LIGHTS
# 2009-12-01 07:45:00  489434    79323W                  WHITE CHERRY LIGHTS
# 2009-12-01 07:45:00  489434     22041         RECORD FRAME 7" SINGLE SIZE
# 2009-12-01 07:45:00  489434     21232       STRAWBERRY CERAMIC TRINKET BOX
# ...                     ...       ...                                  ...
# 2011-12-09 12:50:00  581587     22899         CHILDREN'S APRON DOLLY GIRL
# 2011-12-09 12:50:00  581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 2011-12-09 12:50:00  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 2011-12-09 12:50:00  581587     22138        BAKING SET 9 PIECE RETROSPOT
# 2011-12-09 12:50:00  581587      POST                              POSTAGE
#
#                      Quantity  Price  Customer ID         Country
# InvoiceDate
# 2009-12-01 07:45:00        12   6.95      13085.0  United Kingdom
# 2009-12-01 07:45:00        12   6.75      13085.0  United Kingdom
# 2009-12-01 07:45:00        12   6.75      13085.0  United Kingdom
# 2009-12-01 07:45:00        48   2.10      13085.0  United Kingdom
# 2009-12-01 07:45:00        24   1.25      13085.0  United Kingdom
# ...                       ...    ...          ...             ...
# 2011-12-09 12:50:00         6   2.10      12680.0          France
# 2011-12-09 12:50:00         4   4.15      12680.0          France
# 2011-12-09 12:50:00         4   4.15      12680.0          France
# 2011-12-09 12:50:00         3   4.95      12680.0          France
# 2011-12-09 12:50:00         1  18.00      12680.0          France
#
# [1041671 rows x 7 columns]

# %% [markdown]
# ## Univariate analysis (UA)
# In this section, we will be examining the data in each column either by summarizing the information, getting the frequency, and visualizing it using graphs. Univariate analysis (UA) refers to looking at a single variable/column's values, and performing some kind of analysis on it.
#
# This analysis helps when you're presenting to stakeholders, to help them understand the data better.

# %%
#Create a new column named "Revenue"
df['Revenue'] = df['Price'] * df['Quantity']

# %%
plt.figure(figsize = (16,8))
plt.hist(df['Quantity'])
# Out:
# (array([1.041657e+06, 1.100000e+01, 1.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 2.000000e+00]),
#  array([1.00000e+00, 8.10040e+03, 1.61998e+04, 2.42992e+04, 3.23986e+04,
#         4.04980e+04, 4.85974e+04, 5.66968e+04, 6.47962e+04, 7.28956e+04,
#         8.09950e+04]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(np.log(df['Quantity']))
# Out:
# (array([5.25576e+05, 2.15247e+05, 2.46947e+05, 3.68520e+04, 1.41120e+04,
#         2.55500e+03, 2.89000e+02, 7.90000e+01, 1.20000e+01, 2.00000e+00]),
#  array([ 0.        ,  1.13021427,  2.26042854,  3.39064281,  4.52085708,
#          5.65107135,  6.78128562,  7.91149989,  9.04171416, 10.17192843,
#         11.3021427 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(df['Price'])
# Out:
# (array([1.041631e+06, 2.100000e+01, 8.000000e+00, 2.000000e+00,
#         6.000000e+00, 2.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([1.00000000e-03, 2.51110990e+03, 5.02221880e+03, 7.53332770e+03,
#         1.00444366e+04, 1.25555455e+04, 1.50666544e+04, 1.75777633e+04,
#         2.00888722e+04, 2.25999811e+04, 2.51110900e+04]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(np.log(df['Price']))
# Out:
# (array([1.80000e+01, 2.00000e+00, 1.68200e+03, 2.00332e+05, 6.58512e+05,
#         1.76800e+05, 3.23800e+03, 9.22000e+02, 1.45000e+02, 2.00000e+01]),
#  array([-6.90775528, -5.20387327, -3.49999125, -1.79610924, -0.09222722,
#          1.61165479,  3.3155368 ,  5.01941882,  6.72330083,  8.42718285,
#         10.13106486]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(df['Revenue'])
# Out:
# (array([1.041667e+06, 1.000000e+00, 1.000000e+00, 0.000000e+00,
#         1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([1.00000000e-03, 1.68469609e+04, 3.36939208e+04, 5.05408807e+04,
#         6.73878406e+04, 8.42348005e+04, 1.01081760e+05, 1.17928720e+05,
#         1.34775680e+05, 1.51622640e+05, 1.68469600e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(np.log(df['Revenue']))
# Out:
# (array([1.80000e+01, 0.00000e+00, 9.71000e+02, 1.16138e+05, 5.01189e+05,
#         3.91713e+05, 2.97690e+04, 1.81900e+03, 5.10000e+01, 3.00000e+00]),
#  array([-6.90775528, -5.01352869, -3.1193021 , -1.22507552,  0.66915107,
#          2.56337766,  4.45760425,  6.35183083,  8.24605742, 10.14028401,
#         12.0345106 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
df['Quantity'].plot()
# Out:
# <AxesSubplot:xlabel='InvoiceDate'>

# %% [markdown]
# ## Bivariate analysis (BA)
# Bivariate analysis is a form of analysis where you examine the relationship between two variables. This is usually executed with graphing techniques such as a scatterplot, or boxplots.
#
# Due to the nature of the dataset as is in its current form, there is a limited number of combinations for the two variables but they are nonetheless worth taking a look.

# %%
plt.figure(figsize=(16,8))
plt.scatter(df['Price'], df['Quantity'])

# %%
plt.figure(figsize=(16,8))
plt.scatter(np.log(df['Price']), np.log(df['Quantity']))

# %%
pickle.dump(df, open('Sales_data_update.pickle', 'wb'))
